# %% [markdown]
# # Chapter 10: How to make predictions with a linear regression model

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Get the data

# %%
housingPath = 'housingData.csv'
housing = pd.read_csv(housingPath)

# %%
housing = housing.query('sqft_living < 8000 and price < 1000000 and price > 0')

# %%
housing['has_basement'] = housing['sqft_basement'].apply(
    lambda x: True if x > 0 else False)

# %%
housing = housing.drop(columns=['date','street','city','statezip','country',
                                'sqft_lot','yr_renovated','sqft_basement'])

# %% [markdown]
# ## The Housing dataset

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4207 entries, 0 to 4599
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         4207 non-null   float64
#  1   bedrooms      4207 non-null   float64
#  2   bathrooms     4207 non-null   float64
#  3   sqft_living   4207 non-null   int64
#  4   floors        4207 non-null   float64
#  5   waterfront    4207 non-null   int64
#  6   view          4207 non-null   int64
#  7   condition     4207 non-null   int64
#  8   sqft_above    4207 non-null   int64
#  9   yr_built      4207 non-null   int64
#  10  has_basement  4207 non-null   bool
# dtypes: bool(1), float64(4), int64(6)
# memory usage: 365.6 KB

# %%
housing.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  floors  waterfront  view  \
# 0  313000.0       3.0       1.50         1340     1.5           0     0
# 2  342000.0       3.0       2.00         1930     1.0           0     0
# 3  420000.0       3.0       2.25         2000     1.0           0     0
# 4  550000.0       4.0       2.50         1940     1.0           0     0
# 5  490000.0       2.0       1.00          880     1.0           0     0
#
#    condition  sqft_above  yr_built  has_basement
# 0          3        1340      1955         False
# 2          4        1930      1966         False
# 3          4        1000      1963          True
# 4          4        1140      1976          True
# 5          3         880      1938         False

# %% [markdown]
# ## How to identify correlations with a scatterplot

# %%
sns.relplot(data=housing, x='sqft_living', y='price')

# %%
sns.relplot(data=housing, x='yr_built', y='price')

# %% [markdown]
# ## How to identify correlations with a grid of scatterplots

# %%
sns.pairplot(data=housing,
             y_vars=['price','sqft_living','sqft_above'], 
             x_vars=['price','sqft_living','sqft_above'], 
             diag_kind='kde')

# %% [markdown]
# ## How to identify correlations with r-values

# %%
# housing.corr().head()
housing.corr()
# Out:
#                  price  bedrooms  bathrooms  sqft_living    floors  \
# price         1.000000  0.305046   0.460155     0.607379  0.272151
# bedrooms      0.305046  1.000000   0.516726     0.603655  0.148377
# bathrooms     0.460155  0.516726   1.000000     0.715626  0.495380
# sqft_living   0.607379  0.603655   0.715626     1.000000  0.325647
# floors        0.272151  0.148377   0.495380     0.325647  1.000000
# waterfront    0.073671 -0.032263   0.020700     0.030473  0.008710
# view          0.196460  0.060074   0.112797     0.184432 -0.006647
# condition     0.044926  0.015105  -0.145555    -0.086310 -0.298350
# sqft_above    0.517395  0.466683   0.637045     0.848312  0.526227
# yr_built      0.053012  0.154287   0.521801     0.331001  0.502039
# has_basement  0.152591  0.157001   0.127437     0.175223 -0.305249
#
#               waterfront      view  condition  sqft_above  yr_built  \
# price           0.073671  0.196460   0.044926    0.517395  0.053012
# bedrooms       -0.032263  0.060074   0.015105    0.466683  0.154287
# bathrooms       0.020700  0.112797  -0.145555    0.637045  0.521801
# sqft_living     0.030473  0.184432  -0.086310    0.848312  0.331001
# floors          0.008710 -0.006647  -0.298350    0.526227  0.502039
# waterfront      1.000000  0.321411   0.026089    0.020846 -0.037066
# view            0.321411  1.000000   0.041332    0.075312 -0.064988
# condition       0.026089  0.041332   1.000000   -0.209960 -0.394022
# sqft_above      0.020846  0.075312  -0.209960    1.000000  0.456452
# yr_built       -0.037066 -0.064988  -0.394022    0.456452  1.000000
# has_basement    0.001688  0.152347   0.167838   -0.294986 -0.198823
#
#               has_basement
# price             0.152591
# bedrooms          0.157001
# bathrooms         0.127437
# sqft_living       0.175223
# floors           -0.305249
# waterfront        0.001688
# view              0.152347
# condition         0.167838
# sqft_above       -0.294986
# yr_built         -0.198823
# has_basement      1.000000

# %%
housing.corr()[['price']].sort_values(by='price', ascending=False)
# Out:
#                  price
# price         1.000000
# sqft_living   0.607379
# sqft_above    0.517395
# bathrooms     0.460155
# bedrooms      0.305046
# floors        0.272151
# view          0.196460
# has_basement  0.152591
# waterfront    0.073671
# yr_built      0.053012
# condition     0.044926

# %% [markdown]
# ## How to identify correlations with a heatmap

# %%
sns.heatmap(data=housing.corr(), cmap='Blues', vmin=-1.0, vmax=1.0)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(data=housing.corr()[['price']].sort_values(by='price', ascending=False), 
            annot=True, cmap='Blues', cbar=False, fmt=f'.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## How to create, validate, and use a linear regression model

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
# split the data
x_train, x_test, y_train, y_test = train_test_split(
    housing[['sqft_living']], housing[['price']], 
    test_size=0.33, random_state=42)

# create the model from the training dataset
linearModel = LinearRegression()
linearModel.fit(x_train, y_train)

# validate the model with the test dataset
linearModel.score(x_test, y_test) # this is R2 - coefficient of determination
# Out:
# 0.35072654653322355

# %%
# use the model to make predictions
y_predicted = linearModel.predict(x_test)
y_predicted
# Out:
# array([[355333.11742787],
#        [545363.47687159],
#        [466838.5349527 ],
#        ...,
#        [325493.63949869],
#        [415012.07328623],
#        [394595.58838732]])

# %% [markdown]
# ## How to plot the predicted data

# %%
# put predicted values in a frame
predicted = pd.DataFrame(y_predicted, columns=['price_predicted'])
predicted
# Out:
#       price_predicted
# 0       355333.117428
# 1       545363.476872
# 2       466838.534953
# 3       518664.996619
# 4       539081.481518
# ...               ...
# 1384    518664.996619
# 1385    308218.152277
# 1386    325493.639499
# 1387    415012.073286
# 1388    394595.588387
#
# [1389 rows x 1 columns]

# %%
# combine the test data and the predicted data
combined = predicted.join([x_test.reset_index(drop=True),
                           y_test.reset_index(drop=True)])
combined
# Out:
#       price_predicted  sqft_living     price
# 0       355333.117428         1240  390000.0
# 1       545363.476872         2450  345000.0
# 2       466838.534953         1950  375000.0
# 3       518664.996619         2280  500324.0
# 4       539081.481518         2410  600000.0
# ...               ...          ...       ...
# 1384    518664.996619         2280  820000.0
# 1385    308218.152277          940  249950.0
# 1386    325493.639499         1050  325000.0
# 1387    415012.073286         1620  246500.0
# 1388    394595.588387         1490  259000.0
#
# [1389 rows x 3 columns]

# %%
# melt price and price_predicted columns into a single column
melted = pd.melt(combined, id_vars=['sqft_living'], 
                 value_vars=['price','price_predicted'], 
                 var_name='price_type', value_name='price_value')

melted.head()
# Out:
#    sqft_living price_type  price_value
# 0         1240      price     390000.0
# 1         2450      price     345000.0
# 2         1950      price     375000.0
# 3         2280      price     500324.0
# 4         2410      price     600000.0

# %%
sns.relplot(data=melted, x='sqft_living', y='price_value', 
            hue='price_type')

# %% [markdown]
# ## How to plot the residuals

# %%
combined['residual'] = combined.price - combined.price_predicted
combined.head()

# %%
g = sns.relplot(data=combined, x='sqft_living', y='residual')

# draw a horizontal line where the Y axis is 0
for ax in g.axes.flat:    
    ax.axhline(0, ls='--')

# %% [markdown]
# ## How to plot a linear regression

# %%
sns.lmplot(data=housing, x='sqft_living', y='price', ci=None,
           scatter_kws={'s':5}, line_kws={'color':'red'})

# %% [markdown]
# ## How to plot a logistic regression

# %%
sns.lmplot(data=housing, x='price', y='has_basement', ci=None,
           scatter_kws={'s':1}, line_kws={'color':'red'}, 
           logistic=True)

# %% [markdown]
# ## How to plot a polynormal regression

# %%
# get the data
mortality_data = pd.read_pickle('mortality_data.pkl')
mortality_data.head()

# %%
sns.lmplot(x='Year', y='DeathRate', hue='AgeGroup', data=mortality_data, ci=None,
           markers='d', x_bins=20, order=3)

# %% [markdown]
# ## How to plot a lowess regression

# %%
sns.lmplot(data=mortality_data, x='Year', y='DeathRate', hue='AgeGroup', 
           ci=None, markers='d', x_bins=20, lowess=True)

# %% [markdown]
# ## How to plot residuals with Seaborn

# %%
sns.residplot(data=housing, x='sqft_living', y='price', 
              scatter_kws={'s':5})

# %%
sns.residplot(data=mortality_data, x='Year', y='DeathRate', 
              order=3, scatter_kws={'s':5})
